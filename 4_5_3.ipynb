# %%
import numpy as np
import matplotlib.pyplot as plt
import locale

# %%
f = "0.75 1.7885 2.8269 3.8654 4.9038 5.9423 6.9808   8.0192   9.0577  10.0962  11.1346  12.1731 13.2115 14.25"
f = f.split(" ")
f = [i for i in f if len(i)>0]
f = [float(i) for i in f]
print(f)
# Out:
# [0.75, 1.7885, 2.8269, 3.8654, 4.9038, 5.9423, 6.9808, 8.0192, 9.0577, 10.0962, 11.1346, 12.1731, 13.2115, 14.25]

# %%
a = "13.52  12.11  14.27  16.6   22.91  35.28  60.99  33.38 17.78  10.99   7.47   6.72   4.4    4.07"
a = a.split(" ")
a = [i for i in a if len(i)>0]
a = [float(i) for i in a]
print(a)
# Out:
# [13.52, 12.11, 14.27, 16.6, 22.91, 35.28, 60.99, 33.38, 17.78, 10.99, 7.47, 6.72, 4.4, 4.07]

# %%
da = "0.32  0.92  0.73  2.06  1.75  0.91  0.99  0.36  2.32 0.21  0.48  0.51  0.58  0.63"
da = da.split(" ")
da = [i for i in da if len(i)>0]
da = [float(i) for i in da]
print(da)
# Out:
# [0.32, 0.92, 0.73, 2.06, 1.75, 0.91, 0.99, 0.36, 2.32, 0.21, 0.48, 0.51, 0.58, 0.63]

# %%
fusion = np.c_[f,a,da]
np.savetxt("output.txt",fusion)

# %%
read = np.genfromtxt("output.txt")
