# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# a
value = (2+np.exp(2.8))/(np.sqrt(13)-2)
print(value)
# Out:
# 11.488045914800647

# %%
# b
value = (1-(1+np.log(2))**(-3.5))/(np.sqrt(5)+1)
print(value)
# Out:
# 0.26008973689431575

# %%
# c
value = (2-np.sqrt(2))/(2+np.sqrt(2))
print(value)
# Out:
# 0.17157287525380988
